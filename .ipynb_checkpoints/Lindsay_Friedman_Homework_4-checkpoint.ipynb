# %% [markdown]
# #Homework 4: SQL, Pandas, data munging, and loads of fun
#
# These problem sets encompass two separate topics, covered in class over the past few weeks: (1) basic SQL queries in Python and (2) data munging with Pandas.

# %% [markdown]
# ##Problem set 1: SQL
#
# For the first problem set, you'll be connecting to a remote PostgreSQL server and performing SQL queries inside of Python. You'll need to have either the `psycopg2` library or the `pg8000` library installed on your machine. In the cell below, populate the `host`, `username` and `password` fields with the values we shared with you in class. (If you missed this, ask a fellow student for the credentials.) Make sure to run the cell before you proceed.

# %%
host = "54.175.211.148"
username = "ledeprogram"
password = "g0nz0"

# %% [markdown]
# The code in the following cell should establish a connection to the remote SQL server, regardless of whether or not you have `pg8000` or `pgsql` installed. The connection object will be assigned to a variable called `conn`. Run this cell before you proceed. (The output of the cell should either be `pg8000.core.Connection` or `psycopg2.extensions.connection`, depending on which library you have installed.)

# %%
try:
    import psycopg2
    conn = psycopg2.connect(host=host, user=username, password=password, database="kittens")
except ImportError:
    import pg8000
    conn = pg8000.connect(host=host, user=username, password=password, database="kittens")
type(conn)
# Out:
# psycopg2.extensions.connection

# %% [markdown]
# Okay, now we can get to work! In the cell below, replace the expression `None` with the expression that evaluates to a new cursor object, created from the connection object you established in the cell above. Assign this cursor to a variable called `cursor`.
#
# Expected output: either `<pg8000.core.Cursor instance at ...>` or `<cursor object at ...; closed: 0>`, depending on which library you're using. (The `...` will be a hexadecimal number like `0x12345`. The value will be unique every time you create a new cursor object.)

# %%
cursor = conn.cursor()
print cursor
# Out:
# <cursor object at 0x1074da718; closed: 0>

# %% [markdown]
# Great work! You're now connected to a PostgreSQL server (running on a machine in the ~cloud~) that has a database named `kittens`. In this database, there is a single table called `kittens`. The schema of that table looks like this:
#
# ```
#            Table "public.kittens"
#  Column  |         Type          | Modifiers
# ---------+-----------------------+-----------
#  name    | character varying(80) |
#  age     | integer               |
#  weight  | double precision      |
#  borough | character varying(30) |
# ```
#
# In the cell below, I've written the code necessary to make a query to the database. Fill in the value inside the quotation marks so that the output of the cell is a tuple with the values from all four columns in the first row in the database.
#
# Expected output: `('Monsieur Whiskeurs', 5, 12.2, 'Brooklyn')` (this may be a list, not a tuple, if you're using `pg8000` instead of `psycopg2`.)

# %%
cursor.execute("SELECT name, age, weight, borough FROM kittens")
cursor.fetchone()
# Out:
# ('Monsieur Whiskeurs', 5, 12.2, 'Brooklyn')

# %%
conn.rollback()

# %% [markdown]
# Great work! Now, copy the `cursor.execute(...)` line from the cell above and paste it into the cell below. Write the code necessary to print the following output:
#
# ```
# Monsieur Whiskeurs is 5 years old, weighs 12.2 pounds and lives in Brooklyn
# Fluffles McGee is 2 years old, weighs 8.9 pounds and lives in Queens
# Gazpacho is 9 years old, weighs 11.2 pounds and lives in Brooklyn
# William T. Riker is 4 years old, weighs 13.0 pounds and lives in Manhattan
# Princess is 8 years old, weighs 10.2 pounds and lives in Bronx
# Meowchelle, Ma Belle is 13 years old, weighs 9.1 pounds and lives in Brooklyn
# ```
#
# (Hint: to retrieve all rows from a query, use a `for` loop to iterate over the cursor object. You might want to simply `print` each row first to see how the data is arranged.)

# %%
cursor.execute("SELECT name, age, weight, borough FROM kittens")
for row in cursor:
    print row[0], 'is', row[1], 'years old, weighs', row[2], 'pounds and lives in', row[3]
conn.rollback()
# Out:
# Monsieur Whiskeurs is 5 years old, weighs 12.2 pounds and lives in Brooklyn
# Fluffles McGee is 2 years old, weighs 8.9 pounds and lives in Queens
# Gazpacho is 9 years old, weighs 11.2 pounds and lives in Brooklyn
# William T. Riker is 4 years old, weighs 13.0 pounds and lives in Manhattan
# Princess is 8 years old, weighs 10.2 pounds and lives in Bronx
# Meowchelle, Ma Belle is 13 years old, weighs 9.1 pounds and lives in Brooklyn

# %% [markdown]
# Okay, the hard part is over. The following problem is a test of your SQL skills. In the cell below, modify the string inside of `cursor.execute(...)` so that the query returns the names of every cat from Brooklyn that weights more than 10 pounds. Write a `for` loop to print these results.
#
# Expected output:
# ```
# Monsieur Whiskeurs
# Gazpacho
# ```

# %%
cursor.execute("SELECT name FROM Kittens WHERE weight > 10 and borough = 'Brooklyn' ")
for name in cursor: 
    print name
conn.rollback()
# Out:
# ('Monsieur Whiskeurs',)
# ('Gazpacho',)

# %% [markdown]
# ##Problem set 2: Pandas
#
# Remember, you need to import pandas before you can use it. Make the plots inline too!

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#you need to press enter

# %% [markdown]
# ###Indexing of dataframes
#
# In cells below, import the EduX data set we used in calss from your notebooks directory as a dataframe.
#
# Using `pandas`, slice and dice to get:
# 1. a dataframe with only the User Id and grade columns
# 2. a dataframe with all the columns but only rows 400, 500, 600, 700, 800, 900, 1000, 1100, 1200

# %%
pd.set_option("max_columns",500)
df = pd.read_csv("HMXPC_13.csv")
rdf = df[["userid_DI","grade"]]
rdf
# Out:
#              userid_DI grade
# 0       MHxPC130442623     0
# 1       MHxPC130442623     0
# 2       MHxPC130275857     0
# 3       MHxPC130275857     0
# 4       MHxPC130275857     0
# 5       MHxPC130275857     0
# 6       MHxPC130275857     0
# 7       MHxPC130539455     0
# 8       MHxPC130088379     0
# 9       MHxPC130088379     0
# 10      MHxPC130088379     0
# 11      MHxPC130198098     0
# 12      MHxPC130024894  0.07
# 13      MHxPC130024894     0
# 14      MHxPC130024894     0
# 15      MHxPC130024894     0
# 16      MHxPC130024894     0
# 17      MHxPC130080986     0
# 18      MHxPC130080986     0
# 19      MHxPC130063375     0
# 20      MHxPC130094371     0
# 21      MHxPC130229084     0
# 22      MHxPC130300925     0
# 23      MHxPC130300925     0
# 24      MHxPC130417650     0
# 25      MHxPC130506580     0
# 26      MHxPC130298257     0
# 27      MHxPC130500569     0
# 28      MHxPC130466479     0
# 29      MHxPC130340959  0.05
# ...                ...   ...
# 641108  MHxPC130140735   NaN
# 641109  MHxPC130493130   NaN
# 641110  MHxPC130400592   NaN
# 641111  MHxPC130109892   NaN
# 641112  MHxPC130183007   NaN
# 641113  MHxPC130261281     0
# 641114  MHxPC130481990   NaN
# 641115  MHxPC130528581   NaN
# 641116  MHxPC130555418   NaN
# 641117  MHxPC130408810   NaN
# 641118  MHxPC130040184   NaN
# 641119  MHxPC130566049   NaN
# 641120  MHxPC130374105     0
# 641121  MHxPC130282999   NaN
# 641122  MHxPC130556398     0
# 641123  MHxPC130573334   NaN
# 641124  MHxPC130505931   NaN
# 641125  MHxPC130280976   NaN
# 641126  MHxPC130137331   NaN
# 641127  MHxPC130271624   NaN
# 641128  MHxPC130256541   NaN
# 641129  MHxPC130021638   NaN
# 641130  MHxPC130591057   NaN
# 641131  MHxPC130226305   NaN
# 641132  MHxPC130030805   NaN
# 641133  MHxPC130184108   NaN
# 641134  MHxPC130359782   NaN
# 641135  MHxPC130098513   NaN
# 641136  MHxPC130098513   NaN
# 641137  MHxPC130098513   NaN
#
# [641138 rows x 2 columns]

# %%
df.ix[[400, 500, 600, 700, 800, 900, 1000, 1100, 1200]]
# Out:
#                        course_id       userid_DI  registered  viewed  \
# 400          HarvardX/CS50x/2012  MHxPC130170796           1       1
# 500          HarvardX/CS50x/2012  MHxPC130112140           1       1
# 600   HarvardX/ER22x/2013_Spring  MHxPC130000623           1       1
# 700          HarvardX/CS50x/2012  MHxPC130576970           1       0
# 800    HarvardX/PH207x/2012_Fall  MHxPC130184766           1       1
# 900          HarvardX/CS50x/2012  MHxPC130560886           1       1
# 1000   HarvardX/PH207x/2012_Fall  MHxPC130427773           1       0
# 1100         HarvardX/CS50x/2012  MHxPC130030276           1       1
# 1200  HarvardX/ER22x/2013_Spring  MHxPC130229078           1       1
#
#       explored  certified final_cc_cname_DI LoE_DI  YoB gender grade  \
# 400          1          0             India    NaN  NaN    NaN     0
# 500          0          0     United States    NaN  NaN    NaN     0
# 600          1          1    United Kingdom    NaN  NaN    NaN  0.84
# 700          0          0     Unknown/Other    NaN  NaN    NaN     0
# 800          0          0           Ukraine    NaN  NaN    NaN     0
# 900          0          0    United Kingdom    NaN  NaN    NaN     0
# 1000         0          0     United States    NaN  NaN    NaN     0
# 1100         1          0            Canada    NaN  NaN    NaN     0
# 1200         0          0     United States    NaN  NaN    NaN   NaN
#
#      start_time_DI last_event_DI  nevents  ndays_act  nplay_video  nchapters  \
# 400     2012-07-24           NaN      NaN        NaN          NaN         12
# 500     2012-08-14    2013-04-09        6          2          NaN          2
# 600     2013-01-08    2013-08-08     2426        118          NaN         29
# 700     2012-08-17           NaN      NaN        NaN          NaN        NaN
# 800     2012-07-26    2012-10-21       89          3           12          2
# 900     2012-07-29    2013-05-19       11          2          NaN          1
# 1000    2012-08-17    2012-08-17        1          1          NaN        NaN
# 1100    2013-02-26    2013-03-26       50          2          NaN          9
# 1200    2012-12-20    2013-03-14        4          1          NaN          1
#
#       nforum_posts  roles  incomplete_flag
# 400              0    NaN                1
# 500              0    NaN              NaN
# 600              0    NaN              NaN
# 700              0    NaN              NaN
# 800              0    NaN              NaN
# 900              0    NaN              NaN
# 1000             0    NaN              NaN
# 1100             0    NaN              NaN
# 1200             0    NaN              NaN

# %% [markdown]
# ###Boolean indexing

# %% [markdown]
# Suppose `happydataframe` is a dataframe with 200 rows and two columns "activity" and "endorphin_level".
#
# In the cell below, explain briefly what is the difference between
#
#     happydataframe["activity"]="philately"
#
#  and
#
#     happydataframe["activity"]=="philalely"

# %% [markdown]
# **The first line of code is resetting the method definition to 'philately'. The second is saying it is equal to or the same as philalely. **

# %% [markdown]
# Using the EduX dataset, compute how much video (`nplay_video`) on average the following watched:
# - women
# - men from Spain
# - woman older than 30 from India
#
# Use boolean indexing.

# %%
women_file = df[(df["gender"]=="f")]
men_spain = df[(df["final_cc_cname_DI"]=="Spain") & (df["gender"]=="m")]
women_30older_india = df[(df["final_cc_cname_DI"]=="India") & (df["gender"]=="f") & (df['YoB'] >= 1985)]

# %%
women_file['nplay_video'].mean()
# Out:
# 123.86744825265048

# %%
men_spain['nplay_video'].mean()
# Out:
# 203.84181415929203

# %%
women_30older_india['nplay_video'].mean()
# Out:
# 107.06745510293473

# %% [markdown]
# Using the `.groupby` method create a data frame of how much video on average people from different countries of different genders watched. You can pass `groupby` a list of columns to group by.
#
# something roughly like:
#
# >India
#
# >       F   10
#
# >       M   20
#
# >France
#
# >       F   300
#
# >       M   10
#
# Precise formatting not at issue

# %%
df.groupby(by=["final_cc_cname_DI",'gender'])['nplay_video'].mean()
# Out:
# final_cc_cname_DI  gender
# Australia          f         144.451948
#                    m          90.290523
# Bangladesh         f          57.500000
#                    m          48.906931
# Brazil             f         102.840764
#                    m          88.741951
# Canada             f         101.010855
#                    m          92.313116
# China              f          31.500000
#                    m          73.627063
# Colombia           f         127.148338
#                    m         151.003219
# Egypt              f         200.587646
#                    m          97.102698
# France             f         138.065421
# ...
# Portugal            m         148.938053
# Russian Federation  f         168.257511
#                     m         223.965855
# Spain               f         247.773243
#                     m         203.841814
# Ukraine             f         137.098522
#                     m         189.232401
# United Kingdom      f         135.673239
#                     m          94.552828
# United States       f          97.780967
#                     m          92.837129
#                     o                NaN
# Unknown/Other       f         148.940594
#                     m          76.701493
#                     o                NaN
# Name: nplay_video, Length: 70, dtype: float64

# %% [markdown]
# ##Simple statistical work

# %% [markdown]
# Download a small auto mileage data set from
#
# http://www.columbia.edu/~mj340/auto-mpg.csv. (This is a sample data set included in the `Bokeh` package)
#
# Using this auto mileage data set, find the average mpg (miles per gallon) per year for all cars and plot the values for each year. Include a title on your plot. Use panda's `groupby` function and its .plot() method.

# %%
pd.set_option('display.max_rows', 2000)
df = pd.read_csv("auto-mpg.csv")
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 6    14.0    8  454.0  220    4354    9.0  70       1
# 7    14.0    8  440.0  215    4312    8.5  70       1
# 8    14.0    8  455.0  225    4425   10.0  70       1
# 9    15.0    8  390.0  190    3850    8.5  70       1
# 10   15.0    8  383.0  170    3563   10.0  70       1
# 11   14.0    8  340.0  160    3609    8.0  70       1
# 12   15.0    8  400.0  150    3761    9.5  70       1
# 13   14.0    8  455.0  225    3086   10.0  70       1
# 14   24.0    4  113.0   95    2372   15.0  70       3
# 15   22.0    6  198.0   95    2833   15.5  70       1
# 16   18.0    6  199.0   97    2774   15.5  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 18   27.0    4   97.0   88    2130   14.5  70       3
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 20   25.0    4  110.0   87    2672   17.5  70       2
# 21   24.0    4  107.0   90    2430   14.5  70       2
# 22   25.0    4  104.0   95    2375   17.5  70       2
# 23   26.0    4  121.0  113    2234   12.5  70       2
# 24   21.0    6  199.0   90    2648   15.0  70       1
# 25   10.0    8  360.0  215    4615   14.0  70       1
# 26   10.0    8  307.0  200    4376   15.0  70       1
# 27   11.0    8  318.0  210    4382   13.5  70       1
# 28    9.0    8  304.0  193    4732   18.5  70       1
# 29   27.0    4   97.0   88    2130   14.5  71       3
# 30   28.0    4  140.0   90    2264   15.5  71       1
# 31   25.0    4  113.0   95    2228   14.0  71       3
# 32   19.0    6  232.0  100    2634   13.0  71       1
# 33   16.0    6  225.0  105    3439   15.5  71       1
# 34   17.0    6  250.0  100    3329   15.5  71       1
# 35   19.0    6  250.0   88    3302   15.5  71       1
# 36   18.0    6  232.0  100    3288   15.5  71       1
# 37   14.0    8  350.0  165    4209   12.0  71       1
# 38   14.0    8  400.0  175    4464   11.5  71       1
# 39   14.0    8  351.0  153    4154   13.5  71       1
# 40   14.0    8  318.0  150    4096   13.0  71       1
# 41   12.0    8  383.0  180    4955   11.5  71       1
# 42   13.0    8  400.0  170    4746   12.0  71       1
# 43   13.0    8  400.0  175    5140   12.0  71       1
# 44   18.0    6  258.0  110    2962   13.5  71       1
# 45   22.0    4  140.0   72    2408   19.0  71       1
# 334  27.2    4  135.0   84    2490   15.7  81       1
# 335  26.6    4  151.0   84    2635   16.4  81       1
# 336  25.8    4  156.0   92    2620   14.4  81       1
# 337  23.5    6  173.0  110    2725   12.6  81       1
# 338  30.0    4  135.0   84    2385   12.9  81       1
# 339  39.1    4   79.0   58    1755   16.9  81       3
# 340  39.0    4   86.0   64    1875   16.4  81       1
# 341  35.1    4   81.0   60    1760   16.1  81       3
# 342  32.3    4   97.0   67    2065   17.8  81       3
# 343  37.0    4   85.0   65    1975   19.4  81       3
# 344  37.7    4   89.0   62    2050   17.3  81       3
# 345  34.1    4   91.0   68    1985   16.0  81       3
# 346  34.7    4  105.0   63    2215   14.9  81       1
# 347  34.4    4   98.0   65    2045   16.2  81       1
# 348  29.9    4   98.0   65    2380   20.7  81       1
# 349  33.0    4  105.0   74    2190   14.2  81       2
# 350  33.7    4  107.0   75    2210   14.4  81       3
# 351  32.4    4  108.0   75    2350   16.8  81       3
# 352  32.9    4  119.0  100    2615   14.8  81       3
# 353  31.6    4  120.0   74    2635   18.3  81       3
# 354  28.1    4  141.0   80    3230   20.4  81       2
# 355  30.7    6  145.0   76    3160   19.6  81       2
# 356  25.4    6  168.0  116    2900   12.6  81       3
# 357  24.2    6  146.0  120    2930   13.8  81       3
# 358  22.4    6  231.0  110    3415   15.8  81       1
# 359  26.6    8  350.0  105    3725   19.0  81       1
# 360  20.2    6  200.0   88    3060   17.1  81       1
# 361  17.6    6  225.0   85    3465   16.6  81       1
# 362  28.0    4  112.0   88    2605   19.6  82       1
# 363  27.0    4  112.0   88    2640   18.6  82       1
# 364  34.0    4  112.0   88    2395   18.0  82       1
# 365  31.0    4  112.0   85    2575   16.2  82       1
# 366  29.0    4  135.0   84    2525   16.0  82       1
# 367  27.0    4  151.0   90    2735   18.0  82       1
# 368  24.0    4  140.0   92    2865   16.4  82       1
# 369  36.0    4  105.0   74    1980   15.3  82       2
# 370  37.0    4   91.0   68    2025   18.2  82       3
# 371  31.0    4   91.0   68    1970   17.6  82       3
# 372  38.0    4  105.0   63    2125   14.7  82       1
# 373  36.0    4   98.0   70    2125   17.3  82       1
# 374  36.0    4  120.0   88    2160   14.5  82       3
# 375  36.0    4  107.0   75    2205   14.5  82       3
# 376  34.0    4  108.0   70    2245   16.9  82       3
# 377  38.0    4   91.0   67    1965   15.0  82       3
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 379  38.0    4   91.0   67    1995   16.2  82       3
# 380  25.0    6  181.0  110    2945   16.4  82       1
# 381  38.0    6  262.0   85    3015   17.0  82       1
# 382  26.0    4  156.0   92    2585   14.5  82       1
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 384  32.0    4  144.0   96    2665   13.9  82       3
# 385  36.0    4  135.0   84    2370   13.0  82       1
# 386  27.0    4  151.0   90    2950   17.3  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                                      name
# 0               chevrolet chevelle malibu
# 1                       buick skylark 320
# 2                      plymouth satellite
# 3                           amc rebel sst
# 4                             ford torino
# 5                        ford galaxie 500
# 6                        chevrolet impala
# 7                       plymouth fury iii
# 8                        pontiac catalina
# 9                      amc ambassador dpl
# 10                    dodge challenger se
# 11                     plymouth 'cuda 340
# 12                  chevrolet monte carlo
# 13                buick estate wagon (sw)
# 14                  toyota corona mark ii
# 15                        plymouth duster
# 16                             amc hornet
# 17                          ford maverick
# 18                           datsun pl510
# 19           volkswagen 1131 deluxe sedan
# 20                            peugeot 504
# 21                            audi 100 ls
# 22                               saab 99e
# 23                               bmw 2002
# 24                            amc gremlin
# 25                              ford f250
# 26                              chevy c20
# 27                             dodge d200
# 28                               hi 1200d
# 29                           datsun pl510
# 30                    chevrolet vega 2300
# 31                          toyota corona
# 32                            amc gremlin
# 33              plymouth satellite custom
# 34              chevrolet chevelle malibu
# 35                        ford torino 500
# 36                            amc matador
# 37                       chevrolet impala
# 38              pontiac catalina brougham
# 39                       ford galaxie 500
# 40                      plymouth fury iii
# 41                      dodge monaco (sw)
# 42               ford country squire (sw)
# 43                    pontiac safari (sw)
# 44             amc hornet sportabout (sw)
# 45                    chevrolet vega (sw)
# 46                       pontiac firebird
# 47                           ford mustang
# 48                     mercury capri 2000
# 49                              opel 1900
# 50                            peugeot 304
# 51                              fiat 124b
# 52                    toyota corolla 1200
# 53                            datsun 1200
# 54                   volkswagen model 111
# 55                       plymouth cricket
# 56                  toyota corona hardtop
# 57                     dodge colt hardtop
# 58                      volkswagen type 3
# 59                         chevrolet vega
# 60                    ford pinto runabout
# 61                       chevrolet impala
# 62                       pontiac catalina
# 63                      plymouth fury iii
# 64                       ford galaxie 500
# 65                     amc ambassador sst
# 66                        mercury marquis
# 67                   buick lesabre custom
# 68             oldsmobile delta 88 royale
# 69                 chrysler newport royal
# 70                        mazda rx2 coupe
# 71                       amc matador (sw)
# 72       chevrolet chevelle concours (sw)
# 73                  ford gran torino (sw)
# 74         plymouth satellite custom (sw)
# 75                        volvo 145e (sw)
# 76                    volkswagen 411 (sw)
# 77                       peugeot 504 (sw)
# 78                        renault 12 (sw)
# 79                        ford pinto (sw)
# 80                        datsun 510 (sw)
# 81            toyouta corona mark ii (sw)
# 82                        dodge colt (sw)
# 83               toyota corolla 1600 (sw)
# 84                      buick century 350
# 85                            amc matador
# 86                       chevrolet malibu
# 87                       ford gran torino
# 88                   dodge coronet custom
# 89               mercury marquis brougham
# 90              chevrolet caprice classic
# 91                               ford ltd
# 92               plymouth fury gran sedan
# 93           chrysler new yorker brougham
# 94               buick electra 225 custom
# 95                amc ambassador brougham
# 96                       plymouth valiant
# 97                  chevrolet nova custom
# 98                             amc hornet
# 99                          ford maverick
# 100                       plymouth duster
# 101               volkswagen super beetle
# 102                      chevrolet impala
# 103                          ford country
# 104                plymouth custom suburb
# 105              oldsmobile vista cruiser
# 106                           amc gremlin
# 107                         toyota carina
# 108                        chevrolet vega
# 109                            datsun 610
# 110                             maxda rx3
# 111                            ford pinto
# 112                      mercury capri v6
# 113                  fiat 124 sport coupe
# 114               chevrolet monte carlo s
# 115                    pontiac grand prix
# 116                              fiat 128
# 117                            opel manta
# 118                            audi 100ls
# 119                           volvo 144ea
# 120                     dodge dart custom
# 121                             saab 99le
# 122                        toyota mark ii
# 123                      oldsmobile omega
# 124                       plymouth duster
# 125                            amc hornet
# 126                        chevrolet nova
# 127                           datsun b210
# 128                            ford pinto
# 129                   toyota corolla 1200
# 130                        chevrolet vega
# 131     chevrolet chevelle malibu classic
# 132                           amc matador
# 133            plymouth satellite sebring
# 134                      ford gran torino
# 135              buick century luxus (sw)
# 136             dodge coronet custom (sw)
# 137                 ford gran torino (sw)
# 138                      amc matador (sw)
# 139                              audi fox
# 140                     volkswagen dasher
# 141                            opel manta
# 142                         toyota corona
# 143                            datsun 710
# 144                            dodge colt
# 145                              fiat 128
# 146                           fiat 124 tc
# 147                           honda civic
# 148                                subaru
# 149                             fiat x1.9
# 150               plymouth valiant custom
# 151                        chevrolet nova
# 152                       mercury monarch
# 153                         ford maverick
# 154                      pontiac catalina
# 155                     chevrolet bel air
# 156                   plymouth grand fury
# 157                              ford ltd
# 158                         buick century
# 159             chevroelt chevelle malibu
# 160                           amc matador
# 161                         plymouth fury
# 162                         buick skyhawk
# 163                   chevrolet monza 2+2
# 164                       ford mustang ii
# 165                        toyota corolla
# 166                            ford pinto
# 167                           amc gremlin
# 168                         pontiac astro
# 169                         toyota corona
# 170                     volkswagen dasher
# 171                            datsun 710
# 172                            ford pinto
# 173                     volkswagen rabbit
# 174                             amc pacer
# 175                            audi 100ls
# 176                           peugeot 504
# 177                           volvo 244dl
# 178                             saab 99le
# 179                      honda civic cvcc
# 180                              fiat 131
# 181                             opel 1900
# 182                              capri ii
# 183                            dodge colt
# 184                          renault 12tl
# 185     chevrolet chevelle malibu classic
# 186                dodge coronet brougham
# 187                           amc matador
# 188                      ford gran torino
# 189                      plymouth valiant
# 190                        chevrolet nova
# 191                         ford maverick
# 192                            amc hornet
# 193                    chevrolet chevette
# 194                       chevrolet woody
# 195                             vw rabbit
# 196                           honda civic
# 197                        dodge aspen se
# 198                     ford granada ghia
# 199                    pontiac ventura sj
# 200                         amc pacer d/l
# 201                     volkswagen rabbit
# 202                          datsun b-210
# 203                        toyota corolla
# 204                            ford pinto
# 205                             volvo 245
# 206            plymouth volare premier v8
# 207                           peugeot 504
# 208                        toyota mark ii
# 209                    mercedes-benz 280s
# 210                      cadillac seville
# 211                             chevy c10
# 212                             ford f108
# 213                            dodge d100
# 214                     honda accord cvcc
# 215               buick opel isuzu deluxe
# 216                         renault 5 gtl
# 217                     plymouth arrow gs
# 218                 datsun f-10 hatchback
# 219             chevrolet caprice classic
# 220            oldsmobile cutlass supreme
# 221                 dodge monaco brougham
# 222               mercury cougar brougham
# 223                    chevrolet concours
# 224                         buick skylark
# 225                plymouth volare custom
# 226                          ford granada
# 227                 pontiac grand prix lj
# 228          chevrolet monte carlo landau
# 229                      chrysler cordoba
# 230                      ford thunderbird
# 231              volkswagen rabbit custom
# 232                 pontiac sunbird coupe
# 233               toyota corolla liftback
# 234                   ford mustang ii 2+2
# 235                    chevrolet chevette
# 236                        dodge colt m/m
# 237                             subaru dl
# 238                     volkswagen dasher
# 239                            datsun 810
# 240                              bmw 320i
# 241                            mazda rx-4
# 242       volkswagen rabbit custom diesel
# 243                           ford fiesta
# 244                      mazda glc deluxe
# 245                        datsun b210 gx
# 246                      honda civic cvcc
# 247     oldsmobile cutlass salon brougham
# 248                        dodge diplomat
# 249                  mercury monarch ghia
# 250                    pontiac phoenix lj
# 251                      chevrolet malibu
# 252                  ford fairmont (auto)
# 253                   ford fairmont (man)
# 254                       plymouth volare
# 255                           amc concord
# 256                 buick century special
# 257                        mercury zephyr
# 258                           dodge aspen
# 259                       amc concord d/l
# 260          chevrolet monte carlo landau
# 261       buick regal sport coupe (turbo)
# 262                           ford futura
# 263                       dodge magnum xe
# 264                    chevrolet chevette
# 265                         toyota corona
# 266                            datsun 510
# 267                            dodge omni
# 268             toyota celica gt liftback
# 269                      plymouth sapporo
# 270                oldsmobile starfire sx
# 271                         datsun 200-sx
# 272                             audi 5000
# 273                           volvo 264gl
# 274                            saab 99gle
# 275                         peugeot 604sl
# 276                   volkswagen scirocco
# 277                       honda accord lx
# 278                     pontiac lemans v6
# 279                      mercury zephyr 6
# 280                       ford fairmont 4
# 281                      amc concord dl 6
# 282                         dodge aspen 6
# 283             chevrolet caprice classic
# 284                       ford ltd landau
# 285                 mercury grand marquis
# 286                       dodge st. regis
# 287               buick estate wagon (sw)
# 288              ford country squire (sw)
# 289         chevrolet malibu classic (sw)
# 290  chrysler lebaron town @ country (sw)
# 291                      vw rabbit custom
# 292                      maxda glc deluxe
# 293           dodge colt hatchback custom
# 294                         amc spirit dl
# 295                    mercedes benz 300d
# 296                     cadillac eldorado
# 297                           peugeot 504
# 298     oldsmobile cutlass salon brougham
# 299                      plymouth horizon
# 300                  plymouth horizon tc3
# 301                            datsun 210
# 302                    fiat strada custom
# 303                 buick skylark limited
# 304                    chevrolet citation
# 305             oldsmobile omega brougham
# 306                       pontiac phoenix
# 307                             vw rabbit
# 308                 toyota corolla tercel
# 309                    chevrolet chevette
# 310                            datsun 310
# 311                    chevrolet citation
# 312                         ford fairmont
# 313                           amc concord
# 314                           dodge aspen
# 315                             audi 4000
# 316                toyota corona liftback
# 317                             mazda 626
# 318                  datsun 510 hatchback
# 319                        toyota corolla
# 320                             mazda glc
# 321                            dodge colt
# 322                            datsun 210
# 323                  vw rabbit c (diesel)
# 324                    vw dasher (diesel)
# 325                   audi 5000s (diesel)
# 326                    mercedes-benz 240d
# 327                   honda civic 1500 gl
# 328                             subaru dl
# 329                      vokswagen rabbit
# 330                         datsun 280-zx
# 331                         mazda rx-7 gs
# 332                     triumph tr7 coupe
# 333                          honda accord
# 334                      plymouth reliant
# 335                         buick skylark
# 336                dodge aries wagon (sw)
# 337                    chevrolet citation
# 338                      plymouth reliant
# 339                        toyota starlet
# 340                        plymouth champ
# 341                      honda civic 1300
# 342                                subaru
# 343                        datsun 210 mpg
# 344                         toyota tercel
# 345                           mazda glc 4
# 346                    plymouth horizon 4
# 347                        ford escort 4w
# 348                        ford escort 2h
# 349                      volkswagen jetta
# 350                         honda prelude
# 351                        toyota corolla
# 352                          datsun 200sx
# 353                             mazda 626
# 354             peugeot 505s turbo diesel
# 355                          volvo diesel
# 356                       toyota cressida
# 357                     datsun 810 maxima
# 358                         buick century
# 359                 oldsmobile cutlass ls
# 360                       ford granada gl
# 361                chrysler lebaron salon
# 362                    chevrolet cavalier
# 363              chevrolet cavalier wagon
# 364             chevrolet cavalier 2-door
# 365            pontiac j2000 se hatchback
# 366                        dodge aries se
# 367                       pontiac phoenix
# 368                  ford fairmont futura
# 369                   volkswagen rabbit l
# 370                    mazda glc custom l
# 371                      mazda glc custom
# 372                plymouth horizon miser
# 373                        mercury lynx l
# 374                      nissan stanza xe
# 375                          honda accord
# 376                        toyota corolla
# 377                           honda civic
# 378                    honda civic (auto)
# 379                         datsun 310 gx
# 380                 buick century limited
# 381     oldsmobile cutlass ciera (diesel)
# 382            chrysler lebaron medallion
# 383                        ford granada l
# 384                      toyota celica gt
# 385                     dodge charger 2.2
# 386                      chevrolet camaro
# 387                       ford mustang gl
# 388                             vw pickup
# 389                         dodge rampage
# 390                           ford ranger
# 391                            chevy s-10

# %%
mpg_mean = df.groupby(by=['name','yr'])['mpg'].mean()
mpg_mean[:15].dropna().plot(kind='bar')

# %% [markdown]
# In the data base design, the manufacturer and car type are in a single string field (Ford Galaxie), rather than splitting the manufacturer (Ford) from the particular model (Galaxie). Using regular expressions or any other technique, separate the manufacturer from the mode and create two new columns for the manufacturer and the car models.
# 362  28.0    4  112.0   88    2605   19.6  82       1
# 363  27.0    4  112.0   88    2640   18.6  82       1
# 364  34.0    4  112.0   88    2395   18.0  82       1
# 365  31.0    4  112.0   85    2575   16.2  82       1
# 366  29.0    4  135.0   84    2525   16.0  82       1
# 367  27.0    4  151.0   90    2735   18.0  82       1
# 368  24.0    4  140.0   92    2865   16.4  82       1
# 369  36.0    4  105.0   74    1980   15.3  82       2
# 370  37.0    4   91.0   68    2025   18.2  82       3
# 371  31.0    4   91.0   68    1970   17.6  82       3
# 372  38.0    4  105.0   63    2125   14.7  82       1
# 373  36.0    4   98.0   70    2125   17.3  82       1
# 374  36.0    4  120.0   88    2160   14.5  82       3
# 375  36.0    4  107.0   75    2205   14.5  82       3
# 376  34.0    4  108.0   70    2245   16.9  82       3
# 377  38.0    4   91.0   67    1965   15.0  82       3
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 379  38.0    4   91.0   67    1995   16.2  82       3
# 380  25.0    6  181.0  110    2945   16.4  82       1
# 381  38.0    6  262.0   85    3015   17.0  82       1
# 382  26.0    4  156.0   92    2585   14.5  82       1
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 384  32.0    4  144.0   96    2665   13.9  82       3
# 385  36.0    4  135.0   84    2370   13.0  82       1
# 386  27.0    4  151.0   90    2950   17.3  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                                      name manufacturer  \
# 0               chevrolet chevelle malibu    chevrolet
# 1                       buick skylark 320        buick
# 2                      plymouth satellite     plymouth
# 3                           amc rebel sst          amc
# 4                             ford torino         ford
# 5                        ford galaxie 500         ford
# 6                        chevrolet impala    chevrolet
# 7                       plymouth fury iii     plymouth
# 8                        pontiac catalina      pontiac
# 9                      amc ambassador dpl          amc
# 10                    dodge challenger se        dodge
# 11                     plymouth 'cuda 340     plymouth
# 12                  chevrolet monte carlo    chevrolet
# 13                buick estate wagon (sw)        buick
# 14                  toyota corona mark ii       toyota
# 15                        plymouth duster     plymouth
# 16                             amc hornet          amc
# 17                          ford maverick         ford
# 18                           datsun pl510       datsun
# 19           volkswagen 1131 deluxe sedan   volkswagen
# 20                            peugeot 504      peugeot
# 21                            audi 100 ls         audi
# 22                               saab 99e         saab
# 23                               bmw 2002          bmw
# 24                            amc gremlin          amc
# 25                              ford f250         ford
# 26                              chevy c20        chevy
# 27                             dodge d200        dodge
# 28                               hi 1200d           hi
# 29                           datsun pl510       datsun
# 30                    chevrolet vega 2300    chevrolet
# 31                          toyota corona       toyota
# 32                            amc gremlin          amc
# 33              plymouth satellite custom     plymouth
# 34              chevrolet chevelle malibu    chevrolet
# 35                        ford torino 500         ford
# 36                            amc matador          amc
# 37                       chevrolet impala    chevrolet
# 38              pontiac catalina brougham      pontiac
# 39                       ford galaxie 500         ford
# 40                      plymouth fury iii     plymouth
# 41                      dodge monaco (sw)        dodge
# 42               ford country squire (sw)         ford
# 43                    pontiac safari (sw)      pontiac
# 44             amc hornet sportabout (sw)          amc
# 45                    chevrolet vega (sw)    chevrolet
# 46                       pontiac firebird      pontiac
# 47                           ford mustang         ford
# 48                     mercury capri 2000      mercury
# 49                              opel 1900         opel
# 50                            peugeot 304      peugeot
# 51                              fiat 124b         fiat
# 52                    toyota corolla 1200       toyota
# 53                            datsun 1200       datsun
# 54                   volkswagen model 111   volkswagen
# 55                       plymouth cricket     plymouth
# 56                  toyota corona hardtop       toyota
# 57                     dodge colt hardtop        dodge
# 58                      volkswagen type 3   volkswagen
# 59                         chevrolet vega    chevrolet
# 60                    ford pinto runabout         ford
# 61                       chevrolet impala    chevrolet
# 62                       pontiac catalina      pontiac
# 63                      plymouth fury iii     plymouth
# 64                       ford galaxie 500         ford
# 65                     amc ambassador sst          amc
# 66                        mercury marquis      mercury
# 67                   buick lesabre custom        buick
# 68             oldsmobile delta 88 royale   oldsmobile
# 69                 chrysler newport royal     chrysler
# 70                        mazda rx2 coupe        mazda
# 71                       amc matador (sw)          amc
# 72       chevrolet chevelle concours (sw)    chevrolet
# 73                  ford gran torino (sw)         ford
# 74         plymouth satellite custom (sw)     plymouth
# 75                        volvo 145e (sw)        volvo
# 76                    volkswagen 411 (sw)   volkswagen
# 77                       peugeot 504 (sw)      peugeot
# 78                        renault 12 (sw)      renault
# 79                        ford pinto (sw)         ford
# 80                        datsun 510 (sw)       datsun
# 81            toyouta corona mark ii (sw)      toyouta
# 82                        dodge colt (sw)        dodge
# 83               toyota corolla 1600 (sw)       toyota
# 84                      buick century 350        buick
# 85                            amc matador          amc
# 86                       chevrolet malibu    chevrolet
# 87                       ford gran torino         ford
# 88                   dodge coronet custom        dodge
# 89               mercury marquis brougham      mercury
# 90              chevrolet caprice classic    chevrolet
# 91                               ford ltd         ford
# 92               plymouth fury gran sedan     plymouth
# 93           chrysler new yorker brougham     chrysler
# 94               buick electra 225 custom        buick
# 95                amc ambassador brougham          amc
# 96                       plymouth valiant     plymouth
# 97                  chevrolet nova custom    chevrolet
# 98                             amc hornet          amc
# 99                          ford maverick         ford
# 100                       plymouth duster     plymouth
# 101               volkswagen super beetle   volkswagen
# 102                      chevrolet impala    chevrolet
# 103                          ford country         ford
# 104                plymouth custom suburb     plymouth
# 105              oldsmobile vista cruiser   oldsmobile
# 106                           amc gremlin          amc
# 107                         toyota carina       toyota
# 108                        chevrolet vega    chevrolet
# 109                            datsun 610       datsun
# 110                             maxda rx3        maxda
# 111                            ford pinto         ford
# 112                      mercury capri v6      mercury
# 113                  fiat 124 sport coupe         fiat
# 114               chevrolet monte carlo s    chevrolet
# 115                    pontiac grand prix      pontiac
# 116                              fiat 128         fiat
# 117                            opel manta         opel
# 118                            audi 100ls         audi
# 119                           volvo 144ea        volvo
# 120                     dodge dart custom        dodge
# 121                             saab 99le         saab
# 122                        toyota mark ii       toyota
# 123                      oldsmobile omega   oldsmobile
# 124                       plymouth duster     plymouth
# 125                            amc hornet          amc
# 126                        chevrolet nova    chevrolet
# 127                           datsun b210       datsun
# 128                            ford pinto         ford
# 129                   toyota corolla 1200       toyota
# 130                        chevrolet vega    chevrolet
# 131     chevrolet chevelle malibu classic    chevrolet
# 132                           amc matador          amc
# 133            plymouth satellite sebring     plymouth
# 134                      ford gran torino         ford
# 135              buick century luxus (sw)        buick
# 136             dodge coronet custom (sw)        dodge
# 137                 ford gran torino (sw)         ford
# 138                      amc matador (sw)          amc
# 139                              audi fox         audi
# 140                     volkswagen dasher   volkswagen
# 141                            opel manta         opel
# 142                         toyota corona       toyota
# 143                            datsun 710       datsun
# 144                            dodge colt        dodge
# 145                              fiat 128         fiat
# 146                           fiat 124 tc         fiat
# 147                           honda civic        honda
# 148                                subaru         fiat
# 149                             fiat x1.9     plymouth
# 150               plymouth valiant custom    chevrolet
# 151                        chevrolet nova      mercury
# 152                       mercury monarch         ford
# 153                         ford maverick      pontiac
# 154                      pontiac catalina    chevrolet
# 155                     chevrolet bel air     plymouth
# 156                   plymouth grand fury         ford
# 157                              ford ltd        buick
# 158                         buick century    chevroelt
# 159             chevroelt chevelle malibu          amc
# 160                           amc matador     plymouth
# 161                         plymouth fury        buick
# 162                         buick skyhawk    chevrolet
# 163                   chevrolet monza 2+2         ford
# 164                       ford mustang ii       toyota
# 165                        toyota corolla         ford
# 166                            ford pinto          amc
# 167                           amc gremlin      pontiac
# 168                         pontiac astro       toyota
# 169                         toyota corona   volkswagen
# 170                     volkswagen dasher       datsun
# 171                            datsun 710         ford
# 172                            ford pinto   volkswagen
# 173                     volkswagen rabbit          amc
# 174                             amc pacer         audi
# 175                            audi 100ls      peugeot
# 176                           peugeot 504        volvo
# 177                           volvo 244dl         saab
# 178                             saab 99le        honda
# 179                      honda civic cvcc         fiat
# 180                              fiat 131         opel
# 181                             opel 1900        capri
# 182                              capri ii        dodge
# 183                            dodge colt      renault
# 184                          renault 12tl    chevrolet
# 185     chevrolet chevelle malibu classic        dodge
# 186                dodge coronet brougham          amc
# 187                           amc matador         ford
# 188                      ford gran torino     plymouth
# 189                      plymouth valiant    chevrolet
# 190                        chevrolet nova         ford
# 191                         ford maverick          amc
# 192                            amc hornet    chevrolet
# 193                    chevrolet chevette    chevrolet
# 194                       chevrolet woody           vw
# 195                             vw rabbit        honda
# 196                           honda civic        dodge
# 197                        dodge aspen se         ford
# 198                     ford granada ghia      pontiac
# 199                    pontiac ventura sj          amc
# 200                         amc pacer d/l   volkswagen
# 201                     volkswagen rabbit       datsun
# 202                          datsun b-210       toyota
# 203                        toyota corolla         ford
# 204                            ford pinto        volvo
# 205                             volvo 245     plymouth
# 206            plymouth volare premier v8      peugeot
# 207                           peugeot 504       toyota
# 208                        toyota mark ii         benz
# 209                    mercedes-benz 280s     cadillac
# 210                      cadillac seville        chevy
# 211                             chevy c10         ford
# 212                             ford f108        dodge
# 213                            dodge d100        honda
# 214                     honda accord cvcc        buick
# 215               buick opel isuzu deluxe      renault
# 216                         renault 5 gtl     plymouth
# 217                     plymouth arrow gs       datsun
# 218                 datsun f-10 hatchback    chevrolet
# 219             chevrolet caprice classic   oldsmobile
# 220            oldsmobile cutlass supreme        dodge
# 221                 dodge monaco brougham      mercury
# 222               mercury cougar brougham    chevrolet
# 223                    chevrolet concours        buick
# 224                         buick skylark     plymouth
# 225                plymouth volare custom         ford
# 226                          ford granada      pontiac
# 227                 pontiac grand prix lj    chevrolet
# 228          chevrolet monte carlo landau     chrysler
# 229                      chrysler cordoba         ford
# 230                      ford thunderbird   volkswagen
# 231              volkswagen rabbit custom      pontiac
# 232                 pontiac sunbird coupe       toyota
# 233               toyota corolla liftback         ford
# 234                   ford mustang ii 2+2    chevrolet
# 235                    chevrolet chevette        dodge
# 236                        dodge colt m/m       subaru
# 237                             subaru dl   volkswagen
# 238                     volkswagen dasher       datsun
# 239                            datsun 810          bmw
# 240                              bmw 320i        mazda
# 241                            mazda rx-4   volkswagen
# 242       volkswagen rabbit custom diesel         ford
# 243                           ford fiesta        mazda
# 244                      mazda glc deluxe       datsun
# 245                        datsun b210 gx        honda
# 246                      honda civic cvcc   oldsmobile
# 247     oldsmobile cutlass salon brougham        dodge
# 248                        dodge diplomat      mercury
# 249                  mercury monarch ghia      pontiac
# 250                    pontiac phoenix lj    chevrolet
# 251                      chevrolet malibu         ford
# 252                  ford fairmont (auto)         ford
# 253                   ford fairmont (man)     plymouth
# 254                       plymouth volare          amc
# 255                           amc concord        buick
# 256                 buick century special      mercury
# 257                        mercury zephyr        dodge
# 258                           dodge aspen          amc
# 259                       amc concord d/l    chevrolet
# 260          chevrolet monte carlo landau        buick
# 261       buick regal sport coupe (turbo)         ford
# 262                           ford futura        dodge
# 263                       dodge magnum xe    chevrolet
# 264                    chevrolet chevette       toyota
# 265                         toyota corona       datsun
# 266                            datsun 510        dodge
# 267                            dodge omni       toyota
# 268             toyota celica gt liftback     plymouth
# 269                      plymouth sapporo   oldsmobile
# 270                oldsmobile starfire sx       datsun
# 271                         datsun 200-sx         audi
# 272                             audi 5000        volvo
# 273                           volvo 264gl         saab
# 274                            saab 99gle      peugeot
# 275                         peugeot 604sl   volkswagen
# 276                   volkswagen scirocco        honda
# 277                       honda accord lx      pontiac
# 278                     pontiac lemans v6      mercury
# 279                      mercury zephyr 6         ford
# 280                       ford fairmont 4          amc
# 281                      amc concord dl 6        dodge
# 282                         dodge aspen 6    chevrolet
# 283             chevrolet caprice classic         ford
# 284                       ford ltd landau      mercury
# 285                 mercury grand marquis        dodge
# 286                       dodge st. regis        buick
# 287               buick estate wagon (sw)         ford
# 288              ford country squire (sw)    chevrolet
# 289         chevrolet malibu classic (sw)     chrysler
# 290  chrysler lebaron town @ country (sw)           vw
# 291                      vw rabbit custom        maxda
# 292                      maxda glc deluxe        dodge
# 293           dodge colt hatchback custom          amc
# 294                         amc spirit dl     mercedes
# 295                    mercedes benz 300d     cadillac
# 296                     cadillac eldorado      peugeot
# 297                           peugeot 504   oldsmobile
# 298     oldsmobile cutlass salon brougham     plymouth
# 299                      plymouth horizon     plymouth
# 300                  plymouth horizon tc3       datsun
# 301                            datsun 210         fiat
# 302                    fiat strada custom        buick
# 303                 buick skylark limited    chevrolet
# 304                    chevrolet citation   oldsmobile
# 305             oldsmobile omega brougham      pontiac
# 306                       pontiac phoenix           vw
# 307                             vw rabbit       toyota
# 308                 toyota corolla tercel    chevrolet
# 309                    chevrolet chevette       datsun
# 310                            datsun 310    chevrolet
# 311                    chevrolet citation         ford
# 312                         ford fairmont          amc
# 313                           amc concord        dodge
# 314                           dodge aspen         audi
# 315                             audi 4000       toyota
# 316                toyota corona liftback        mazda
# 317                             mazda 626       datsun
# 318                  datsun 510 hatchback       toyota
# 319                        toyota corolla        mazda
# 320                             mazda glc        dodge
# 321                            dodge colt       datsun
# 322                            datsun 210           vw
# 323                  vw rabbit c (diesel)           vw
# 324                    vw dasher (diesel)         audi
# 325                   audi 5000s (diesel)         benz
# 326                    mercedes-benz 240d        honda
# 327                   honda civic 1500 gl       subaru
# 328                             subaru dl    vokswagen
# 329                      vokswagen rabbit       datsun
# 330                         datsun 280-zx        mazda
# 331                         mazda rx-7 gs      triumph
# 332                     triumph tr7 coupe        honda
# 333                          honda accord     plymouth
# 334                      plymouth reliant        buick
# 335                         buick skylark        dodge
# 336                dodge aries wagon (sw)    chevrolet
# 337                    chevrolet citation     plymouth
# 338                      plymouth reliant       toyota
# 339                        toyota starlet     plymouth
# 340                        plymouth champ        honda
# 341                      honda civic 1300       datsun
# 342                                subaru       toyota
# 343                        datsun 210 mpg        mazda
# 344                         toyota tercel     plymouth
# 345                           mazda glc 4         ford
# 346                    plymouth horizon 4         ford
# 347                        ford escort 4w   volkswagen
# 348                        ford escort 2h        honda
# 349                      volkswagen jetta       toyota
# 350                         honda prelude       datsun
# 351                        toyota corolla        mazda
# 352                          datsun 200sx      peugeot
# 353                             mazda 626        volvo
# 354             peugeot 505s turbo diesel       toyota
# 355                          volvo diesel       datsun
# 356                       toyota cressida        buick
# 357                     datsun 810 maxima   oldsmobile
# 358                         buick century         ford
# 359                 oldsmobile cutlass ls     chrysler
# 360                       ford granada gl    chevrolet
# 361                chrysler lebaron salon    chevrolet
# 362                    chevrolet cavalier    chevrolet
# 363              chevrolet cavalier wagon      pontiac
# 364             chevrolet cavalier 2-door        dodge
# 365            pontiac j2000 se hatchback      pontiac
# 366                        dodge aries se         ford
# 367                       pontiac phoenix   volkswagen
# 368                  ford fairmont futura        mazda
# 369                   volkswagen rabbit l        mazda
# 370                    mazda glc custom l     plymouth
# 371                      mazda glc custom      mercury
# 372                plymouth horizon miser       nissan
# 373                        mercury lynx l        honda
# 374                      nissan stanza xe       toyota
# 375                          honda accord        honda
# 376                        toyota corolla        honda
# 377                           honda civic       datsun
# 378                    honda civic (auto)        buick
# 379                         datsun 310 gx   oldsmobile
# 380                 buick century limited     chrysler
# 381     oldsmobile cutlass ciera (diesel)         ford
# 382            chrysler lebaron medallion       toyota
# 383                        ford granada l        dodge
# 384                      toyota celica gt    chevrolet
# 385                     dodge charger 2.2         ford
# 386                      chevrolet camaro           vw
# 387                       ford mustang gl        dodge
# 388                             vw pickup         ford
# 389                         dodge rampage        chevy
# 390                           ford ranger          NaN
# 391                            chevy s-10          NaN
#
#                            model
# 0                chevelle malibu
# 1                    skylark 320
# 2                      satellite
# 3                      rebel sst
# 4                         torino
# 5                    galaxie 500
# 6                         impala
# 7                       fury iii
# 8                       catalina
# 9                 ambassador dpl
# 10                 challenger se
# 11                     'cuda 340
# 12                   monte carlo
# 13             estate wagon (sw)
# 14                corona mark ii
# 15                        duster
# 16                        hornet
# 17                      maverick
# 18                         pl510
# 19             1131 deluxe sedan
# 20                           504
# 21                        100 ls
# 22                           99e
# 23                          2002
# 24                       gremlin
# 25                          f250
# 26                           c20
# 27                          d200
# 28                         1200d
# 29                         pl510
# 30                     vega 2300
# 31                        corona
# 32                       gremlin
# 33              satellite custom
# 34               chevelle malibu
# 35                    torino 500
# 36                       matador
# 37                        impala
# 38             catalina brougham
# 39                   galaxie 500
# 40                      fury iii
# 41                   monaco (sw)
# 42           country squire (sw)
# 43                   safari (sw)
# 44        hornet sportabout (sw)
# 45                     vega (sw)
# 46                      firebird
# 47                       mustang
# 48                    capri 2000
# 49                          1900
# 50                           304
# 51                          124b
# 52                  corolla 1200
# 53                          1200
# 54                     model 111
# 55                       cricket
# 56                corona hardtop
# 57                  colt hardtop
# 58                        type 3
# 59                          vega
# 60                pinto runabout
# 61                        impala
# 62                      catalina
# 63                      fury iii
# 64                   galaxie 500
# 65                ambassador sst
# 66                       marquis
# 67                lesabre custom
# 68               delta 88 royale
# 69                 newport royal
# 70                     rx2 coupe
# 71                  matador (sw)
# 72        chevelle concours (sw)
# 73              gran torino (sw)
# 74         satellite custom (sw)
# 75                     145e (sw)
# 76                      411 (sw)
# 77                      504 (sw)
# 78                       12 (sw)
# 79                    pinto (sw)
# 80                      510 (sw)
# 81           corona mark ii (sw)
# 82                     colt (sw)
# 83             corolla 1600 (sw)
# 84                   century 350
# 85                       matador
# 86                        malibu
# 87                   gran torino
# 88                coronet custom
# 89              marquis brougham
# 90               caprice classic
# 91                           ltd
# 92               fury gran sedan
# 93           new yorker brougham
# 94            electra 225 custom
# 95           ambassador brougham
# 96                       valiant
# 97                   nova custom
# 98                        hornet
# 99                      maverick
# 100                       duster
# 101                 super beetle
# 102                       impala
# 103                      country
# 104                custom suburb
# 105                vista cruiser
# 106                      gremlin
# 107                       carina
# 108                         vega
# 109                          610
# 110                          rx3
# 111                        pinto
# 112                     capri v6
# 113              124 sport coupe
# 114                monte carlo s
# 115                   grand prix
# 116                          128
# 117                        manta
# 118                        100ls
# 119                        144ea
# 120                  dart custom
# 121                         99le
# 122                      mark ii
# 123                        omega
# 124                       duster
# 125                       hornet
# 126                         nova
# 127                         b210
# 128                        pinto
# 129                 corolla 1200
# 130                         vega
# 131      chevelle malibu classic
# 132                      matador
# 133            satellite sebring
# 134                  gran torino
# 135           century luxus (sw)
# 136          coronet custom (sw)
# 137             gran torino (sw)
# 138                 matador (sw)
# 139                          fox
# 140                       dasher
# 141                        manta
# 142                       corona
# 143                          710
# 144                         colt
# 145                          128
# 146                       124 tc
# 147                        civic
# 148                         x1.9
# 149               valiant custom
# 150                         nova
# 151                      monarch
# 152                     maverick
# 153                     catalina
# 154                      bel air
# 155                   grand fury
# 156                          ltd
# 157                      century
# 158              chevelle malibu
# 159                      matador
# 160                         fury
# 161                      skyhawk
# 162                    monza 2+2
# 163                   mustang ii
# 164                      corolla
# 165                        pinto
# 166                      gremlin
# 167                        astro
# 168                       corona
# 169                       dasher
# 170                          710
# 171                        pinto
# 172                       rabbit
# 173                        pacer
# 174                        100ls
# 175                          504
# 176                        244dl
# 177                         99le
# 178                   civic cvcc
# 179                          131
# 180                         1900
# 181                           ii
# 182                         colt
# 183                         12tl
# 184      chevelle malibu classic
# 185             coronet brougham
# 186                      matador
# 187                  gran torino
# 188                      valiant
# 189                         nova
# 190                     maverick
# 191                       hornet
# 192                     chevette
# 193                        woody
# 194                       rabbit
# 195                        civic
# 196                     aspen se
# 197                 granada ghia
# 198                   ventura sj
# 199                    pacer d/l
# 200                       rabbit
# 201                        b-210
# 202                      corolla
# 203                        pinto
# 204                          245
# 205            volare premier v8
# 206                          504
# 207                      mark ii
# 208                         280s
# 209                      seville
# 210                          c10
# 211                         f108
# 212                         d100
# 213                  accord cvcc
# 214            opel isuzu deluxe
# 215                        5 gtl
# 216                     arrow gs
# 217               f-10 hatchback
# 218              caprice classic
# 219              cutlass supreme
# 220              monaco brougham
# 221              cougar brougham
# 222                     concours
# 223                      skylark
# 224                volare custom
# 225                      granada
# 226                grand prix lj
# 227           monte carlo landau
# 228                      cordoba
# 229                  thunderbird
# 230                rabbit custom
# 231                sunbird coupe
# 232             corolla liftback
# 233               mustang ii 2+2
# 234                     chevette
# 235                     colt m/m
# 236                           dl
# 237                       dasher
# 238                          810
# 239                         320i
# 240                         rx-4
# 241         rabbit custom diesel
# 242                       fiesta
# 243                   glc deluxe
# 244                      b210 gx
# 245                   civic cvcc
# 246       cutlass salon brougham
# 247                     diplomat
# 248                 monarch ghia
# 249                   phoenix lj
# 250                       malibu
# 251              fairmont (auto)
# 252               fairmont (man)
# 253                       volare
# 254                      concord
# 255              century special
# 256                       zephyr
# 257                        aspen
# 258                  concord d/l
# 259           monte carlo landau
# 260    regal sport coupe (turbo)
# 261                       futura
# 262                    magnum xe
# 263                     chevette
# 264                       corona
# 265                          510
# 266                         omni
# 267           celica gt liftback
# 268                      sapporo
# 269                  starfire sx
# 270                       200-sx
# 271                         5000
# 272                        264gl
# 273                        99gle
# 274                        604sl
# 275                     scirocco
# 276                    accord lx
# 277                    lemans v6
# 278                     zephyr 6
# 279                   fairmont 4
# 280                 concord dl 6
# 281                      aspen 6
# 282              caprice classic
# 283                   ltd landau
# 284                grand marquis
# 285                    st. regis
# 286            estate wagon (sw)
# 287          country squire (sw)
# 288          malibu classic (sw)
# 289  lebaron town @ country (sw)
# 290                rabbit custom
# 291                   glc deluxe
# 292        colt hatchback custom
# 293                    spirit dl
# 294                    benz 300d
# 295                     eldorado
# 296                          504
# 297       cutlass salon brougham
# 298                      horizon
# 299                  horizon tc3
# 300                          210
# 301                strada custom
# 302              skylark limited
# 303                     citation
# 304               omega brougham
# 305                      phoenix
# 306                       rabbit
# 307               corolla tercel
# 308                     chevette
# 309                          310
# 310                     citation
# 311                     fairmont
# 312                      concord
# 313                        aspen
# 314                         4000
# 315              corona liftback
# 316                          626
# 317                510 hatchback
# 318                      corolla
# 319                          glc
# 320                         colt
# 321                          210
# 322            rabbit c (diesel)
# 323              dasher (diesel)
# 324               5000s (diesel)
# 325                         240d
# 326                civic 1500 gl
# 327                           dl
# 328                       rabbit
# 329                       280-zx
# 330                      rx-7 gs
# 331                    tr7 coupe
# 332                       accord
# 333                      reliant
# 334                      skylark
# 335             aries wagon (sw)
# 336                     citation
# 337                      reliant
# 338                      starlet
# 339                        champ
# 340                   civic 1300
# 341                      210 mpg
# 342                       tercel
# 343                        glc 4
# 344                    horizon 4
# 345                    escort 4w
# 346                    escort 2h
# 347                        jetta
# 348                      prelude
# 349                      corolla
# 350                        200sx
# 351                          626
# 352            505s turbo diesel
# 353                       diesel
# 354                     cressida
# 355                   810 maxima
# 356                      century
# 357                   cutlass ls
# 358                   granada gl
# 359                lebaron salon
# 360                     cavalier
# 361               cavalier wagon
# 362              cavalier 2-door
# 363           j2000 se hatchback
# 364                     aries se
# 365                      phoenix
# 366              fairmont futura
# 367                     rabbit l
# 368                 glc custom l
# 369                   glc custom
# 370                horizon miser
# 371                       lynx l
# 372                    stanza xe
# 373                       accord
# 374                      corolla
# 375                        civic
# 376                 civic (auto)
# 377                       310 gx
# 378              century limited
# 379       cutlass ciera (diesel)
# 380            lebaron medallion
# 381                    granada l
# 382                    celica gt
# 383                  charger 2.2
# 384                       camaro
# 385                   mustang gl
# 386                       pickup
# 387                      rampage
# 388                       ranger
# 389                         s-10
# 390                          NaN
# 391                          NaN

# %% [markdown]
# Now:
#
# Find the average mpg for each manufacturer
#
# Plot the changing mpg for four manufacturers

# %%
mpg_mean = df.groupby(by=['manufacturer'])['mpg'].mean()
mpg_mean[:4].dropna().plot(kind='bar')
